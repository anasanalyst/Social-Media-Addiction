# %%
'''
Importing essential libraries with which we will be able to work on our data. on the side I imported the warnings with which 
we will not see unnecassry errors.

'''
import pandas as pd 
import matplotlib.pylab as plt
import numpy as np
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
pd.set_option('display.max_rows', 100)  # Set this to however many rows you want to see

# %%
df=pd.read_csv(r"C:\Users\Anus\PycharmProjects\Files\Student Social Media\Students Social Media Addiction.csv")

# %%
#we have already loaded the file and now we will check for the information on this

# %%
df
# Out:
#      Student_ID  Age  Gender Academic_Level     Country  \
# 0             1   19  Female  Undergraduate  Bangladesh
# 1             2   22    Male       Graduate       India
# 2             3   20  Female  Undergraduate         USA
# 3             4   18    Male    High School          UK
# 4             5   21    Male       Graduate      Canada
# ..          ...  ...     ...            ...         ...
# 700         701   20  Female  Undergraduate       Italy
# 701         702   23    Male       Graduate      Russia
# 702         703   21  Female  Undergraduate       China
# 703         704   24    Male       Graduate       Japan
# 704         705   19  Female  Undergraduate      Poland
#
#      Avg_Daily_Usage_Hours Most_Used_Platform Affects_Academic_Performance  \
# 0                      5.2          Instagram                          Yes
# 1                      2.1            Twitter                           No
# ...

# %%
#Using the head method
df.head(5)
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
#using the tail method
df.tail(5)
# Out:
#      Student_ID  Age  Gender Academic_Level Country  Avg_Daily_Usage_Hours  \
# 700         701   20  Female  Undergraduate   Italy                    4.7
# 701         702   23    Male       Graduate  Russia                    6.8
# 702         703   21  Female  Undergraduate   China                    5.6
# 703         704   24    Male       Graduate   Japan                    4.3
# 704         705   19  Female  Undergraduate  Poland                    6.2
#
#     Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 700             TikTok                           No                    7.2
# 701          Instagram                          Yes                    5.9
# 702             WeChat                          Yes                    6.7
# 703            Twitter                           No                    7.5
# 704           Facebook                          Yes                    6.3
#
# ...

# %%
#using the info method to see the information about the table/data
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 13 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    object
#  3   Academic_Level                705 non-null    object
#  4   Country                       705 non-null    object
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    object
#  7   Affects_Academic_Performance  705 non-null    object
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    object
#  11  Conflicts_Over_Social_Media   705 non-null    int64
# ...

# %%
#Using the dtype method to see the data types of the columns before starting working on them
df.dtypes
# Out:
# Student_ID                        int64
# Age                               int64
# Gender                           object
# Academic_Level                   object
# Country                          object
# Avg_Daily_Usage_Hours           float64
# Most_Used_Platform               object
# Affects_Academic_Performance     object
# Sleep_Hours_Per_Night           float64
# Mental_Health_Score               int64
# Relationship_Status              object
# Conflicts_Over_Social_Media       int64
# Addicted_Score                    int64
# dtype: object

# %% [raw]
# '''
# from the above we got to know that the data is already in the correct data-types, although we can question abou the avg_daily_usagehours and sleep hours
# column but right now we are only given with hours not the exact date so we need them either float or integer form
# '''

# %%
#Checking for duplicated values 
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Checking for any Na values
df.isna().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %%
#checking for null values if there are any
df.isnull().sum()
# Out:
# Student_ID                      0
# Age                             0
# Gender                          0
# Academic_Level                  0
# Country                         0
# Avg_Daily_Usage_Hours           0
# Most_Used_Platform              0
# Affects_Academic_Performance    0
# Sleep_Hours_Per_Night           0
# Mental_Health_Score             0
# Relationship_Status             0
# Conflicts_Over_Social_Media     0
# Addicted_Score                  0
# dtype: int64

# %%
'''
Since the data doesn't have any duplicated values or any na/null values we are good to go and perfrom our EDA
'''
# Out:
# "\nSince the data doesn't have any duplicated values or any na/null values we are good to go and perfrom our EDA\n"

# %%
df.head(10)
# Out:
#    Student_ID  Age  Gender Academic_Level      Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate   Bangladesh                    5.2
# 1           2   22    Male       Graduate        India                    2.1
# 2           3   20  Female  Undergraduate          USA                    6.0
# 3           4   18    Male    High School           UK                    3.0
# 4           5   21    Male       Graduate       Canada                    4.5
# 5           6   19  Female  Undergraduate    Australia                    7.2
# 6           7   23    Male       Graduate      Germany                    1.5
# 7           8   20  Female  Undergraduate       Brazil                    5.8
# 8           9   18    Male    High School        Japan                    4.0
# 9          10   21  Female       Graduate  South Korea                    3.3
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# ...

# %%
#Making some additional features to the group before i start the data analysis
#Creating a Age group so it can be easier while analysis
bins=[15,20,25,30,35]
labels=['16-20','21-25','26-30','31-35']
df['Age_Group']=pd.cut(df['Age'], bins=bins, labels=labels, right=False)

# %%
#Creating Daily usage group
usage_bins = [0, 2, 4, 6, 12, 24]
usage_labels = ['Minimal (0-2h)', 'Moderate (2-4h)', 'High (4-6h)', 'Very High (6-12h)', 'Extreme (12h+)']
df['Usage_Category'] = pd.cut(df['Avg_Daily_Usage_Hours'], bins=usage_bins, labels=usage_labels)

# %%
# Categorize sleep hours
sleep_bins = [0, 5, 7, 9, 12]
sleep_labels = ['Poor (<5h)', 'Fair (5-7h)', 'Good (7-9h)', 'Excellent (9h+)']
df['Sleep_Category'] = pd.cut(df['Sleep_Hours_Per_Night'], bins=sleep_bins, labels=sleep_labels)

# %%
#1 Starting the EDA with Age distribution and Gender distribution

#Age Distribution
plt.figure(figsize=(16,6))

plt.subplot(1,2,1)
plt.style.use('fivethirtyeight')
sns.histplot(df,x='Age', kde=True, bins=15)
plt.title("Age Distribution of Students", fontsize=15)
plt.xlabel("Ages", fontsize=12)
plt.ylabel('Counts', fontsize='12')

#Gender Distribution
plt.subplot(1,2,2)
gender_counts=df['Gender'].value_counts()
plt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90)
plt.title("Gender Distribution",fontsize=15)
plt.axis('equal')
plt.tight_layout()

# %%
### Now I'm going to do the country and academic level distribution and for both barplot will be used

plt.figure(figsize=(15,5))
sns.set_context('paper')
#top 10Country Level distribution by average hourly usage
plt.subplot(1,2,1)
top_10countries=df.groupby('Country')['Avg_Daily_Usage_Hours'].max().nlargest(10).reset_index()

sns.barplot(top_10countries, x='Country',y='Avg_Daily_Usage_Hours', palette='Set1')
plt.xticks(rotation=45)
plt.title("TOP COUNTRIES SOCIAL USAGE", fontsize=13)
plt.xlabel("Countries", fontsize=12)
plt.ylabel("AVERAGE HOURS", fontsize=12)


#Academic level distribution
plt.subplot(1,2,2)
academic_dist=df['Academic_Level'].value_counts()
sns.barplot(x=academic_dist.index, y=academic_dist.values,palette='Set2')
plt.tight_layout()

# %%
df.head(10)
# Out:
#    Student_ID  Age  Gender Academic_Level      Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate   Bangladesh                    5.2
# 1           2   22    Male       Graduate        India                    2.1
# 2           3   20  Female  Undergraduate          USA                    6.0
# 3           4   18    Male    High School           UK                    3.0
# 4           5   21    Male       Graduate       Canada                    4.5
# 5           6   19  Female  Undergraduate    Australia                    7.2
# 6           7   23    Male       Graduate      Germany                    1.5
# 7           8   20  Female  Undergraduate       Brazil                    5.8
# 8           9   18    Male    High School        Japan                    4.0
# 9          10   21  Female       Graduate  South Korea                    3.3
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 705 entries, 0 to 704
# Data columns (total 16 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Student_ID                    705 non-null    int64
#  1   Age                           705 non-null    int64
#  2   Gender                        705 non-null    object
#  3   Academic_Level                705 non-null    object
#  4   Country                       705 non-null    object
#  5   Avg_Daily_Usage_Hours         705 non-null    float64
#  6   Most_Used_Platform            705 non-null    object
#  7   Affects_Academic_Performance  705 non-null    object
#  8   Sleep_Hours_Per_Night         705 non-null    float64
#  9   Mental_Health_Score           705 non-null    int64
#  10  Relationship_Status           705 non-null    object
#  11  Conflicts_Over_Social_Media   705 non-null    int64
# ...

# %%
''' 2. Social media daily usage hours pattern '''
# Out:
# ' 2. Social media daily usage hours pattern '

# %%
## Average Daily Usage Hours
plt.figure(figsize=(12,6))
sns.histplot(df['Avg_Daily_Usage_Hours'], kde=True, bins=20, color='black')
plt.title("Average Daily Social Media Usage")
plt.xlabel("Hours", fontsize=12)
plt.ylabel("Count", fontsize=12)
plt.axvline(df['Avg_Daily_Usage_Hours'].mean(), color='red', linestyle='--',
           label=f'Mean: {df["Avg_Daily_Usage_Hours"].mean():.2f} hours')
plt.legend()
plt.show()

# %%
## Most used platforms
plt.figure(figsize=(15,7))
platform_counts= df['Most_Used_Platform'].value_counts()
sns.barplot(x=platform_counts.index, y=platform_counts.values, palette='magma')
plt.title('Widely Used Platforms')
plt.xlabel("Platforms",fontsize=12)
plt.ylabel("Counts",fontsize=12)
plt.show()

# %%
## Social media usage by Age and Gender
plt.figure(figsize=(16,7))
plt.style.use('bmh')

#Usage by Age
plt.subplot(1,2,1)
#using the age group I've already made above.
sns.boxplot(df, x='Age_Group', y='Avg_Daily_Usage_Hours', palette='Set1')
plt.title("Social Media Usage by Age")
plt.xlabel("Age_Group")
plt.ylabel('AVG Daily Usage Hours')

#Usage by gender
plt.subplot(1,2,2)

sns.boxplot(df, x='Gender', y='Avg_Daily_Usage_Hours', palette='Set2')
plt.title('Social Media Usage by Gender')
plt.xlabel("Gender")
plt.ylabel('AVG Daily Usage Hours')
plt.show()

# %%
# 3.Mental Health Score VS Social Media Usage

plt.figure(figsize=(10,6))
sns.scatterplot(df, x='Avg_Daily_Usage_Hours', y='Mental_Health_Score', alpha=0.7, hue='Gender')
plt.title("Mental Health Score VS Social Media Usage", fontsize=15)
plt.xlabel("Daily Average Usage Hours")
plt.ylabel('Mental Health Score')
#ADDING A REGRESSION LINE
sns.regplot(df,x='Avg_Daily_Usage_Hours',y='Mental_Health_Score', scatter=False, color='black')
#Calculating the correlation
correlation=df['Avg_Daily_Usage_Hours'].corr(df['Mental_Health_Score'])
plt.annotate(f'Correlation: {correlation:.2f}', xy=(0.05, 0.95), xycoords='axes fraction', fontsize=14 )
plt.show()

# %%
# #### Sleep Hours vs Social Media Usage
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Avg_Daily_Usage_Hours', y='Sleep_Hours_Per_Night', data=df, alpha=0.6, hue='Gender')
plt.title('Sleep Hours vs Social Media Usage', fontsize=14)
plt.xlabel('Average Daily Usage Hours', fontsize=12)
plt.ylabel('Sleep Hours Per Night', fontsize=12)

# Add regression line
sns.regplot(x='Avg_Daily_Usage_Hours', y='Sleep_Hours_Per_Night', data=df, scatter=False, color='red')

# Calculate correlation
correlation2 = df['Avg_Daily_Usage_Hours'].corr(df['Sleep_Hours_Per_Night'])
plt.annotate(f'Correlation2: {correlation:.2f}', xy=(0.05, 0.95), xycoords='axes fraction', fontsize=12)

plt.show()

# %%
# Checking out addiction score by sleeping category using boxplot
plt.figure(figsize=(12,5))
sns.boxplot(df,x='Sleep_Category', y='Addicted_Score', palette='Set1' )
plt.title('Sleep Quality by Addiction Score')
plt.xlabel("Sleep Category")
plt.ylabel('Addiction Score')
plt.show()

# %%
#Relationship status and conflicts Analysis

plt.figure(figsize=(12,5))
sns.boxplot(df, x='Relationship_Status', y='Avg_Daily_Usage_Hours', palette="Set2")
plt.title("Relationship Status by Avg Social Media Usage")
plt.xlabel('Relationship Status')
plt.ylabel('Hourly Usage')
plt.show()

# %%
#Conflicts over social media usage by relationship status
relationship_status=df.groupby('Relationship_Status')['Conflicts_Over_Social_Media'].mean().sort_values(ascending=False).reset_index()
relationship_status
# Out:
#   Relationship_Status  Conflicts_Over_Social_Media
# 0         Complicated                     3.031250
# 1              Single                     2.901042
# 2     In Relationship                     2.761246

# %%
#Social Media Addiction vs Relationship conflicts
plt.figure(figsize=(15,6))

# %%
#plotting Conflicts over social media usage by relationship status
plt.figure(figsize=(14,6))
plt.style.use('fivethirtyeight')
sns.barplot(data=relationship_status, x='Relationship_Status', y='Conflicts_Over_Social_Media',
           palette='magma')
# Out:
# <Axes: xlabel='Relationship_Status', ylabel='Conflicts_Over_Social_Media'>

# %%
df.head()
# Out:
#    Student_ID  Age  Gender Academic_Level     Country  Avg_Daily_Usage_Hours  \
# 0           1   19  Female  Undergraduate  Bangladesh                    5.2
# 1           2   22    Male       Graduate       India                    2.1
# 2           3   20  Female  Undergraduate         USA                    6.0
# 3           4   18    Male    High School          UK                    3.0
# 4           5   21    Male       Graduate      Canada                    4.5
#
#   Most_Used_Platform Affects_Academic_Performance  Sleep_Hours_Per_Night  \
# 0          Instagram                          Yes                    6.5
# 1            Twitter                           No                    7.5
# 2             TikTok                          Yes                    5.0
# 3            YouTube                           No                    7.0
# 4           Facebook                          Yes                    6.0
#
# ...

# %%
# Conflict over Social Media vs Addicted Score\
plt.figure(figsize=(10,7))
plt.style.use('bmh')
sns.scatterplot(df, x='Addicted_Score', y='Conflicts_Over_Social_Media', hue='Gender', alpha=0.7)
plt.title('Addicted Score Vs Conflicts Over Social Media')
plt.xlabel("Addicted Score")
plt.ylabel('Conflicts')

#making regression line
sns.regplot(x='Addicted_Score', y='Conflicts_Over_Social_Media',data=df, scatter=False, color='red')
#doing the correlation as well

correlation3=df['Addicted_Score'].corr(df['Conflicts_Over_Social_Media'])
plt.annotate(f'Correlation3: {correlation:.2f}', xy=(0.5, 0.95), xycoords='axes fraction')
plt.show()

# %%
'''
                     Insights
'''
# Out:
# '\n                     Insights\n'

# %%
'''
In this project, I analyzed survey data on the students social media habits, academic levels, sleep patters, relations ships status 
and mental health to uncover behavioral patterns and correlations, Using python (Pandas, Matplotlib, Seaborn and Nump), I performed 
EDA exploratory data analysis, through which i analsyed key trends.
'''
# Out:
# '\nIn this project, I analyzed survey data on the students social media habits, academic levels, sleep patters, relations ships status \nand mental health to uncover behavioral patterns and correlations, Using python (Pandas, Matplotlib, Seaborn and Nump), I performed \nEDA exploratory data analysis, through which i analsyed key trends.\n'

# %%
'''
Key Findings
1. Demographic & Usage
. Majority of respondents were aged 18-24, with balanced gender distribution.
.Top 10 countries showed the average daily social media usage ranging from 4-8 hours, with notable variations/changes by academic level.

2. Platform popularity
. Instagram and Youtube emerged as the most widely used platforms, followed by TikTok and Facebook.
3.Screen Time Insights
.Average daily usage was 6.2 hours, with significant outliers exceeding 10 hours daily, which means some were having screeen time 
of more than 10 hours.
.Younger age group tended to spend more time online than those who are old, which shows younger kids are very much addicted.
4.Mental Health Correlation
.There was a negative Correlation (-0.45) between daily usage and mental health score, which suggest that the heavier social media 
use is linked to lower mental health ratings and vice versa.
5. Sleep Impact
.Increased daily usage correlation with reduced average sleep hours, suggesting the more the daily usage the less is the sleep.
.Student in the "Poor Sleep" category also recorded higher addiction level.

6. Relation Status
.Student in relationship reported slightly higher daily usage than single peers.
.Addiction scores were positively correlated with conflicts over social media
'''
# Out:
# '\nKey Findings\n1. Demographic & Usage\n. Majority of respondents were aged 18-24, with balanced gender distribution.\n.Top 10 countries showed the average daily social media usage ranging from 4-8 hours, with notable variations/changes by academic level.\n\n2. Platform popularity\n. Instagram and Youtube emerged as the most widely used platforms, followed by TikTok and Facebook.\n3.Screen Time Insights\n.Average daily usage was 6.2 hours, with significant outliers exceeding 10 hours daily, which means some were having screeen time \nof more than 10 hours.\n.Younger age group tended to spend more time online than those who are old, which shows younger kids are very much addicted.\n4.Mental Health Correlation\n.There was a negative Correlation (-0.45) between daily usage and mental health score, which suggest that the heavier social media \nuse is linked to lower mental health ratings and vice versa.\n5. Sleep Impact\n.Increased daily usage correlation with reduced average sleep hour
# ...
